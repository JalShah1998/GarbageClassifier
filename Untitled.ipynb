# %%
import threading
import os, time
def predict(n):
    #function body
    time.sleep(1)
    print("hfihsf")
def mapr():
    #function body
    print("mapr executed")
def capture(n):
    #function body
    n=n+1
    print("capture executed")
    return n
def main():
    # creating threads 
    n=0
    while 1:
        n=capture(n)
        #captured
        t1 = threading.Thread(target=predict,args=(n,)) 
        # start threads
        t1.start()
        
    # wait until threads finish their job 

    
main()
# Out:
# hfihsfhfihsfhfihsf
#
# hfihsf
#
# hfihsf
# hfihsf
# hfihsfhfihsf
#
# hfihsf
# hfihsf
# hfihsf
# hfihsfhfihsfhfihsf
#
#
# hfihsfhfihsf
# hfihsfhfihsf
# hfihsfhfihsf
#
#
#
# hfihsfhfihsf
#
# hfihsfhfihsf
# hfihsf
#
# hfihsfhfihsf
#
# hfihsfhfihsfhfihsfhfihsfhfihsf
#
# hfihsf
#
#
#
# hfihsfhfihsfhfihsf
#
#
# hfihsfhfihsf
#
# hfihsfhfihsfhfihsfhfihsf
#
#
#
# hfihsf
# hfihsf
# hfihsfhfihsf
#
# hfihsfhfihsf
#
# hfihsf
# hfihsfhfihsfhfihsfhfihsfhfihsfhfihsf
#
#
# hfihsf
#
#
#
# hfihsfhfihsf
# hfihsfhfihsfhfihsfhfihsfhfihsf
# hfihsfhfihsf
#
#
# hfihsf
#
# hfihsf
#
#
#
# hfihsfhfihsfhfihsf
#
#
# hfihsfhfihsfhfihsf
#
#
# hfihsfhfihsfhfihsf
#
#
# hfihsf
# hfihsf
# hfihsfhfihsf
# hfihsfhfihsfhfihsf
#
# hfihsf
#
#
# hfihsfhfihsfhfihsfhfihsfhfihsfhfihsfhfihsf
#
#
#
#
#
# hfihsfhfihsfhfihsfhfihsfhfihsf
#
#
#
#
#
# hfihsfhfihsfhfihsfhfihsfhfihsf
# hfihsf
#
# hfihsfhfihsfhfihsfhfihsfhfihsf
#
#
#
#
#
# hfihsfhfihsfhfihsfhfihsfhfihsfhfihsfhfihsfhfihsfhfihsfhfihsfhfihsfhfihsfhfihsf
# ...
#
# ...
